# %%
#change Kernel to "...tensorflow_27
#we are importing packages

import scipy.io
import scipy.misc
import tensorflow as tf
import numpy as np
import time
import os
from IPython.display import Image

from __future__ import print_function
from keras.preprocessing.image import load_img, img_to_array
from scipy.misc import imsave #to be able to save as an image
from scipy.optimize import fmin_l_bfgs_b #to optimize our cost function

from keras.applications import vgg19 #to load vgg19 network
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
import keras
print(tf.__version__)
print(keras.__version__)

from keras.utils.vis_utils import plot_model #to be able to visualize the network
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# Out:
# 1.4.0
# 2.1.2

# %%
# let's load images

content_image_path = './SourceImg/'
style_reference_image_path = './StyleImg/'


contentList = os.listdir(content_image_path)
if ".ipynb_checkpoints" in contentList:
    contentList.remove(".ipynb_checkpoints")
contentList.sort(key=str.lower)


target_image_ref_name = contentList[0]

styleList = os.listdir(style_reference_image_path)
if ".ipynb_checkpoints" in styleList:
    styleList.remove(".ipynb_checkpoints")
styleList.sort(key=str.lower)

styleStack = ""

print(styleList)

# get dimensions (width, height) of the generated picture
width, height = load_img(content_image_path + target_image_ref_name).size

img_nrows = 400 #recale the image to 400 pixel rows 
img_ncols = int(width * img_nrows / height)
# Out:
# ['01_vangoghmuseum-s0031V1962-800.jpg', 'abstract-purple-onion-flowers-color-color.jpg', 'Stained_Glass_Disney.jpg']

# %%
iterations = 20 #we will run 20 iterations during the optiomization. each iteration you get better value. this one is for about 15 min. running. 

#style_iterations = [10,6,8]
#if len(style_iterations) != len(styleList):
#    print("--------------------------------------------------")
#    print("Numbers of iteration do not match numbers of style")
#    print("--------------------------------------------------")

# these are the weights of the different loss components
total_variation_weight = 1.0 
style_weight = 1.0 #the best number authors got from their trials 
content_weight = 0.025 #the best number authors got from their trials

# %%
# pre-process the image: rescaling, running it through VGG19

def preprocess_image(image_path):

    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img


# utility function to convert a tensor into a valid image

def deprocess_image(x):

    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, img_nrows, img_ncols))
        x = x.transpose((1, 2, 0))

    else:

        x = x.reshape((img_nrows, img_ncols, 3))

    # Remove zero-center by mean pixel

    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68

    # 'BGR'->'RGB'

    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

#calculating the mean pixel values of the VGG network. We will use these values for normalization.
#mean = data['meta'][0][0][2][0][0][2]
#mean_pixel = np.mean(mean, axis=(0, 1))
#print(mean_pixel)

# %%
# compute the neural style loss
# first we need to define 4 utility functions
# the gram matrix of an image tensor (feature-wise outer product)

def gram_matrix(x):

    assert K.ndim(x) == 3
    if K.image_data_format() == 'channels_first':
        features = K.batch_flatten(x)
    else:
        features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))

    gram = K.dot(features, K.transpose(features))
    return gram

# %%
# the "style loss" is designed to maintain
# the style of the reference image in the generated image.
# It is based on the gram matrices (which capture style) of
# feature maps from the style reference image
# and from the generated image

def style_loss(style, combination):

    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3

    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
# an auxiliary loss function
# designed to maintain the "content" of the
# base image in the generated image

def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
# the 3rd loss function, total variation loss,
# designed to keep the generated image locally coherent (no big changes)

def total_variation_loss(x):
    assert K.ndim(x) == 4
    if K.image_data_format() == 'channels_first':

        a = K.square(x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, 1:, :img_ncols - 1])
        b = K.square(x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, :img_nrows - 1, 1:])
    else:
        a = K.square(x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
        b = K.square(x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
def eval_loss_and_grads(x):

    if K.image_data_format() == 'channels_first':
        x = x.reshape((1, 3, img_nrows, img_ncols))
    else:
        x = x.reshape((1, img_nrows, img_ncols, 3))

    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# %%
# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.

class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %%
evaluator = Evaluator()

# %%
for style in styleList:
    
    #iterations = style_iterations.pop(0)
    styleAddr = style_reference_image_path + style
    image_style = scipy.misc.imread(styleAddr)
    
    #image_content= scipy.misc.imresize(image_content,(224,224))
    #plt.figure(figsize=(11,11))
    #plt.imshow(image_style)
    
    style_reference_image = K.variable(preprocess_image(styleAddr))
    styleName = style[:style.find(".")]
    styleStack += styleName + '_'

    for content in contentList:
        
        fileAddr = content_image_path + content
        contentName = content[:content.find(".")]


        image_content = scipy.misc.imread(fileAddr)
        

        #image_content= scipy.misc.imresize(image_content,(224,224))
        #plt.figure(figsize=(11,11))
        #plt.imshow(image_content)

        # get tensor representations of our images

        base_image = K.variable(preprocess_image(fileAddr))

        # this will contain our generated image
        if K.image_data_format() == 'channels_first':
            combination_image = K.placeholder((1, 3, img_nrows, img_ncols))
        else:
            combination_image = K.placeholder((1, img_nrows, img_ncols, 3))


        # combine the 3 images (style, content, result image that starts from the white noise) into a single Keras tensor

        input_tensor = K.concatenate([base_image,
                                      style_reference_image,
                                      combination_image], axis=0)

        # build the VGG19 network with our 3 images as input
        # the model will be loaded with pre-trained ImageNet weights

        model = vgg19.VGG19(input_tensor=input_tensor,weights='imagenet', include_top=False)
        print('Model loaded.')

        #plot_model(model, show_shapes=True, to_file='./images/model.png')
        #Image("./images/model.png")
        #for l, layer in enumerate(model.layers):
        #print(layer.name)
        # get the symbolic outputs of each "key" layer (we gave them unique names).
        outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
        # combine these loss functions into a single scalar

        loss = K.variable(0.)
        layer_features = outputs_dict['block5_conv2'] #content features
        base_image_features = layer_features[0, :, :, :]
        combination_features = layer_features[2, :, :, :]
        loss += content_weight * content_loss(base_image_features,
                                              combination_features)

        # style_features
        feature_layers = ['block1_conv1', 'block2_conv1',
                          'block3_conv1', 'block4_conv1',
                          'block5_conv1']

        for layer_name in feature_layers:
            layer_features = outputs_dict[layer_name]
            style_reference_features = layer_features[1, :, :, :]
            combination_features = layer_features[2, :, :, :]
            sl = style_loss(style_reference_features, combination_features)
            loss += (style_weight / len(feature_layers)) * sl

        loss += total_variation_weight * total_variation_loss(combination_image)

        # get the gradients of the generated image wrt the loss

        grads = K.gradients(loss, combination_image)
        outputs = [loss]

        if isinstance(grads, (list, tuple)):
            outputs += grads
        else:
            outputs.append(grads)

        f_outputs = K.function([combination_image], outputs)

        # run scipy-based optimization (L-BFGS) over the pixels of the generated image
        # so as to minimize the neural style loss
        x = preprocess_image(fileAddr)

        
        result_prefix ='./Intermediate_Result/' + styleStack + contentName
        # minimise the loss function

        for i in range(iterations):

            print('Start of iteration', i)
            start_time = time.time()

            x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                             fprime=evaluator.grads, maxfun=20)

            print('Current loss value:', min_val)
            # save current generated image

            img = deprocess_image(x.copy())
            fname = result_prefix + '_at_iteration_%d.png' % i
            imsave(fname, img)
            imsave(fileAddr, img)
            end_time = time.time()

            print('Image saved as', fname)
            print('Iteration %d completed in %ds' % (i, end_time - start_time))

            #image_content= scipy.misc.imresize(image_content,(224,224))
            #plt.figure(figsize=(11,11))
            #plt.imshow(img)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/ipykernel/__main__.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/ipykernel/__main__.py:21: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# Model loaded.
# Start of iteration 0
# Current loss value: 1.98785e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_0.png
# Iteration 0 completed in 54s
# Start of iteration 1
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/ipykernel/__main__.py:113: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/ipykernel/__main__.py:114: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# Current loss value: 1.32198e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_1.png
# Iteration 1 completed in 16s
# Start of iteration 2
# Current loss value: 1.10643e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_2.png
# Iteration 2 completed in 16s
# Start of iteration 3
# Current loss value: 1.00779e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_3.png
# Iteration 3 completed in 16s
# Start of iteration 4
# Current loss value: 9.44957e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_4.png
# Iteration 4 completed in 16s
# Start of iteration 5
# Current loss value: 8.92216e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.41214e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.99932e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.67215e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.35538e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 1_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.88397e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.30786e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.09903e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.81163e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.10458e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.63023e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.2195e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.83587e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.40288e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.05714e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 10_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 2.02692e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.31911e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.09685e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.91385e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.19066e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.70414e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.1842e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.79006e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.45146e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.14469e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 11_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.90689e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.31626e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.11405e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.95779e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.20355e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.62047e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.19157e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.80457e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.41686e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.10672e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 12_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.93071e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.28958e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.08954e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.86698e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.25752e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.76956e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.29175e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.91991e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.53249e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.17814e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 13_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.95102e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.28097e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.08501e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.93054e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.20021e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.58144e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.09727e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.71095e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.41475e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.14571e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 14_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.93869e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.29758e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.10053e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.92467e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.21532e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.64457e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.02388e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.63115e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.27989e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 6.89226e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 15_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 2.00289e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.34648e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.12813e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 1.00416e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.30763e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.73721e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.32336e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.89636e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.54577e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.25538e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 16_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.9968e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.30835e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.09046e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.79494e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.01275e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.52117e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.08609e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.7548e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.4243e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.14478e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 17_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.98988e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.32659e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.11542e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 1.00374e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.29668e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.69936e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.25816e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.83472e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.51308e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.23498e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 2_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.95309e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.3163e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.11774e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 1.0197e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.48426e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.97375e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.36278e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.92567e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.52879e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.19924e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 3_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.95449e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_0.png
# Iteration 0 completed in 17s
# Start of iteration 1
# Current loss value: 1.32312e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.12838e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 1.00941e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.37293e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.82898e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.31966e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.94708e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.5681e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.22749e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 4_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.99072e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 1.33816e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.11858e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 1.02051e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.40543e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.78839e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.30504e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.90455e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.60565e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.29143e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 5_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.90055e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 1.31351e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.11716e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 1.00706e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.34259e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.82691e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.36315e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.89708e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.53824e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.2453e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 6_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.95604e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 1.31793e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.12488e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 1.02531e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.41203e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.81491e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.32712e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.9305e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.60159e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.2147e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 7_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.90335e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 1.2679e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.08221e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.85378e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.09095e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.56348e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.17167e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.82711e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.52972e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.25857e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 8_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.93552e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 1.29241e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 1.09768e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 9.98545e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 9.24543e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 8.73535e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 8.28957e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 7.94605e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_7.png
# Iteration 7 completed in 17s
# Start of iteration 8
# Current loss value: 7.59115e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_8.png
# Iteration 8 completed in 17s
# Start of iteration 9
# Current loss value: 7.31974e+08
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Layer 9_at_iteration_9.png
# Iteration 9 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 3.9423e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 1_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.60912e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 1_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.23222e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 1_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.08662e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 1_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.00141e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 1_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.94826e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 1_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.16745e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 10_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.73731e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 10_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.32954e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 10_at_iteration_2.png
# Iteration 2 completed in 16s
# Start of iteration 3
# Current loss value: 2.1567e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 10_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.04469e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 10_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.97495e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 10_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.07765e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 11_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.68553e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 11_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.27352e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 11_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.09596e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 11_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 1.99262e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 11_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.93952e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 11_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.21179e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 12_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.73445e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 12_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.26832e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 12_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.10322e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 12_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.01829e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 12_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.96184e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 12_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.12164e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 13_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.70574e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 13_at_iteration_1.png
# Iteration 1 completed in 16s
# Start of iteration 2
# Current loss value: 2.2928e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 13_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.11889e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 13_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.02097e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 13_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.96426e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 13_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.02773e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 14_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.66886e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 14_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.26009e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 14_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.09796e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 14_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.00315e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 14_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.94176e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 14_at_iteration_5.png
# Iteration 5 completed in 16s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.01591e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 15_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.6572e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 15_at_iteration_1.png
# Iteration 1 completed in 16s
# Start of iteration 2
# Current loss value: 2.23989e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 15_at_iteration_2.png
# Iteration 2 completed in 16s
# Start of iteration 3
# Current loss value: 2.08194e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 15_at_iteration_3.png
# Iteration 3 completed in 16s
# Start of iteration 4
# Current loss value: 2.00237e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 15_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.94537e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 15_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.19512e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 16_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.68953e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 16_at_iteration_1.png
# Iteration 1 completed in 16s
# Start of iteration 2
# Current loss value: 2.28388e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 16_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.10078e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 16_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.01273e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 16_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.95991e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 16_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.17332e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 17_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.73091e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 17_at_iteration_1.png
# Iteration 1 completed in 16s
# Start of iteration 2
# Current loss value: 2.2911e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 17_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.14062e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 17_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.04287e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 17_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.96987e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 17_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.10884e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 2_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.67672e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 2_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.28698e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 2_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.11135e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 2_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.01211e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 2_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.95453e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 2_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.1417e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 3_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 2.72011e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 3_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.28105e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 3_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.11466e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 3_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.0232e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 3_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.961e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 3_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 3.91737e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 4_at_iteration_0.png
# Iteration 0 completed in 19s
# Start of iteration 1
# Current loss value: 2.61522e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 4_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.24859e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 4_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.084e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 4_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.00616e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 4_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.94473e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 4_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 4.07426e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 5_at_iteration_0.png
# Iteration 0 completed in 19s
# Start of iteration 1
# Current loss value: 2.6594e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 5_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.26917e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 5_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.10462e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 5_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 2.01159e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 5_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 1.95148e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 5_at_iteration_5.png
# Iteration 5 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 3.94071e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 6_at_iteration_0.png
# Iteration 0 completed in 19s
# Start of iteration 1
# Current loss value: 2.59487e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 6_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 2.24078e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_Layer 6_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 2.09121e+10
# ...
# Current loss value: 4.43101e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 17_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.27383e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 17_at_iteration_7.png
# Iteration 7 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.1389e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 2_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 7.03694e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 2_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 5.8797e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 2_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 5.29008e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 2_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 4.91985e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 2_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 4.65906e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 2_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 4.45939e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 2_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.29958e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 2_at_iteration_7.png
# Iteration 7 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.13935e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 3_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 7.04685e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 3_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 5.77153e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 3_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 5.16331e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 3_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 4.80519e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 3_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 4.56848e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 3_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 4.37627e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 3_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.22123e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 3_at_iteration_7.png
# Iteration 7 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.15058e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 4_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 7.10131e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 4_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 5.99824e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 4_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 5.49506e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 4_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 5.18632e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 4_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 4.92854e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 4_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 4.73354e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 4_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.57562e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 4_at_iteration_7.png
# Iteration 7 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.16907e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 5_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 7.03626e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 5_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 5.83113e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 5_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 5.24325e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 5_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 4.88717e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 5_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 4.64331e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 5_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 4.45055e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 5_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.29875e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 5_at_iteration_7.png
# Iteration 7 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.13301e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 6_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 7.12651e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 6_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 5.96518e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 6_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 5.35319e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 6_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 4.98369e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 6_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 4.76057e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 6_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 4.59977e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 6_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.46554e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 6_at_iteration_7.png
# Iteration 7 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.16258e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 7_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 7.03704e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 7_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 5.80075e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 7_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 5.17742e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 7_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 4.80292e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 7_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 4.55292e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 7_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 4.36443e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 7_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.2157e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 7_at_iteration_7.png
# Iteration 7 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.15344e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 8_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 7.19118e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 8_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 5.97544e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 8_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 5.37202e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 8_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 4.99821e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 8_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 4.73323e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 8_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 4.52264e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 8_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.35733e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 8_at_iteration_7.png
# Iteration 7 completed in 17s
# Model loaded.
# Start of iteration 0
# Current loss value: 1.14198e+10
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 9_at_iteration_0.png
# Iteration 0 completed in 20s
# Start of iteration 1
# Current loss value: 7.00669e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 9_at_iteration_1.png
# Iteration 1 completed in 17s
# Start of iteration 2
# Current loss value: 5.83553e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 9_at_iteration_2.png
# Iteration 2 completed in 17s
# Start of iteration 3
# Current loss value: 5.25571e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 9_at_iteration_3.png
# Iteration 3 completed in 17s
# Start of iteration 4
# Current loss value: 4.90642e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 9_at_iteration_4.png
# Iteration 4 completed in 17s
# Start of iteration 5
# Current loss value: 4.66675e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 9_at_iteration_5.png
# Iteration 5 completed in 17s
# Start of iteration 6
# Current loss value: 4.47993e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 9_at_iteration_6.png
# Iteration 6 completed in 17s
# Start of iteration 7
# Current loss value: 4.33882e+09
# Image saved as ./Intermediate_Result/01_vangoghmuseum-s0031V1962-800_Stained_Glass_Disney_abstract-purple-onion-flowers-color-color_Layer 9_at_iteration_7.png
# Iteration 7 completed in 17s
